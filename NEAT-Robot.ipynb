# %%
import sys
import os
from src.botEnv import botEnv
import filepath as file
import random #nur zum testen
import neat
import pybullet as p
import time
import math
import numpy as np

# %%
###Alle möglichen Einstellungen zu NEAT außer der Config File können hier gemacht werden


goalPositions = 'Pos3-Axis'        #Name des Files mit den Zielpositionen
conf = 'config.txt'                #Name der Config file die verwendet werden soll
globalGoal = []                    #globale Variable für die Zielpositionen
fitnessDevelopment = []            #globale Variable zum Verlauf der Fitness
bestGenome = []                    #speicher das beste genome ab
numAxis = 3                       #Anzahl der Achsen, die der Roboter bewegen kann. 1,2,3,6,7
maxDist = 1.842                    #maixmale Distanz zweier Punkte, hier über Roboter Bewegungs Test bestimmbar
FF = 2                            #welche Fitnessfunktion verwendet werden soll, 1 oder 2
orVer = False                      #ob die Orientierung mit betrachtet werden soll
maxStep = 400                      #Simulationsschritte Pro Punkt
GUI = True                         #GUI anzeigen oder nicht. Beim Pixelflux unbedignt auf False setzen
numOfPoints = 10                   #Punkte die pro Generation angefahren werden sollen
maxGenerations = 1000              #Anzahln der Generationen, nach der spätestens abgebrochen werden soll

# %%
#Hilfsfunktionen
def setGlobalGoal(file):
    global globalGoal
    with open(file, "rb") as f: #welche Zielpositionen geladen werden sollen
        globalGoal = pickle.load(f)
    f.close()

def calcDistance(firstPos, secondPos): # berechnet euklidische Distanz zwischen Punkten
    dist = math.sqrt(((firstPos[0]-secondPos[0])**2)+((firstPos[1]-secondPos[1])**2)+((firstPos[2]-secondPos[2])**2))
    return dist

def getStartPos(num): #bestimmt eine gewisse menge an start Positionen
    pos = []
    rows = num/2
    for i in range(num):
        pos.append([3*(i%10), (i/10)*3, 0])
    return pos

def fitnessFunction1(head, headOrientation, goal, goalOrientation, ver): #in der arbeit beschriebene FF1
        distance = calcDistance(head, goal)
        if ver == 1:
            d_roll = abs(headOrientation[0] - goalOrientation[0])
            d_pitch = abs(headOrientation[1] - goalOrientation[1])
            d_jaw = abs(headOrientation[2] - goalOrientation[2])
            
            d_or = [d_pitch, d_jaw, d_roll]
        else:
            d_or = [0.,0.,0.]
        return distance, d_or

def fitnessFunction2(head, headOrientation, goal, goalOrientation, startDistance, orDistance, orVer): #in der arbeit beschriebenen FF2

    distance = calcDistance(head, goal)
    if startDistance == 0:
        startDistance = 0.001
    score = (1 - (distance/startDistance)) * 100
    if score < 0:
        score = 0
    if orVer:
        d_jaw = abs(headOrientation[0] - goalOrientation[0])
        d_pitch = abs(headOrientation[1] - goalOrientation[1])
        d_roll = abs(headOrientation[2] - goalOrientation[2])
        for i in range(3):
            if orDistance[i] == 0:
                orDistance[i] = 0.01
        score_roll = (1 - d_roll/orDistance[0])
        if score_roll < 0:
            score_roll = 0
        score_pitch = (1 - d_pitch/orDistance[1])
        if score_pitch < 0:
            score_pitch = 0
            score_jaw = (1 - d_jaw/orDistance[2])
        if score_jaw < 0:
            score_jaw = 0


        score_o = ((score_jaw + score_pitch + score_roll) / 3) * 100
        score += score_o
    return score

def cartToSpher(x,y,z): #Umrechnung in das für den Roboter angepasste Koordinatensystem
    z = z-0.36
    r = math.sqrt(x*x+y*y+z*z)
    a = z/r
    theta = math.acos(a)
    phi = math.atan2(y,x)
    pol = [r,theta,phi]
    return pol

def getGoalPosition(num, orVer): #Bestimmen der Zielpositionen für eine Generation
    global globalGoal
    goalPos = []
    goalSpher = []
    goalOr = []
    for i in range(num):
        index = int(random.uniform(0, len(globalGoal)))
        pos = globalGoal[index]
        goal = [pos[0],pos[1],pos[2]]
        goalS = cartToSpher(pos[0],pos[1],pos[2])
        if len(pos)>3 and orVer:
            goalO = [pos[3],pos[4],pos[5]]
        else:
            goalO = [0.,0.,0.]
        goalPos.append(goal)
        goalSpher.append(goalS)
        goalOr.append(goalO)
    return goalPos, goalSpher, goalOr

# %%
#Funktion zur Evaluation der Genome
def evalGenome(genomes, config):


    
    
    global bestGenome
    global fitnessVerlauf
    ge = []
    nets = []
    bots = []
    distances = []

    goalKart, goalSpher, goalOrientation= getGoalPosition(numOfPoints, orVer)
    startPos = getStartPos(len(genomes))

    if GUI:
        p.connect(p.GUI) #Mit GUI
    else:
        p.connect(p.DIRECT) #ohne GUI

    index = 0
    for genome_id, genome in genomes:
        net = neat.nn.FeedForwardNetwork.create(genome,config)
        nets.append(net)
        ge.append(genome)
        start = startPos[index]
        bots.append(botEnv(startPos = start, numAxis = numAxis))
        genome.fitness = 0
        index += 1
    collisions = 0
    index = 0
    stepCount = 0
    step = 0

####Beginn der Simulation### 
    while(step < numOfPoints):
        for bot in bots:
            if not bot.collisionFlag:
                bot.setStepStart()
        while(stepCount<maxStep):
            for i, bot in enumerate(bots):
                if not bot.collisionFlag:
                    endeffektor = bot.getBotHeadPos() #pos kartesische Koordinaten [0] = x, [1] = y, [2] = x
                    endeffektorSpher = bot.getBotSpherical() #pos räumliche Polarkoordinaten [0] = r, [1] = theta, [2] = phi
                    endeffektorOrientation = list(p.getEulerFromQuaternion(p.getLinkState(bot.botId,bot.numJoints-1)[1])) #[0] = roll, [1] = pitch, [2] = yaw
                    #p.getJointState(bot.botId, X)[0] gibt den Zustand der Achse X an, in dem Programm sind Achsen von 0-6 nummeriert
                    #Als zielpunkte stehen goalKart - kartesischen Koordinaten [0] = x, [1] = y, [2] = z
                                        #  goalSpher- räumliche Polarkoordiante [0] = r, [1] = theta, [2] = phi
                                        # goalOrientierung - Zielorientierung des Endeffektor [0] = roll, [1] = pitch, [2] = yaw
###########################################################################################################################################################                          
                    #JE NACH VERSUCH HIER DIE INPUTS ANPASSEN, AN WAS MAN VERWENDEN MÖCHTE, ANZAHL MUSS DER IN DER CONFIG FESTGELEGTEN ENTSPRECHEN
                    output = nets[i].activate((
                                                p.getJointState(bot.botId, 0)[0],
                                                p.getJointState(bot.botId, 1)[0],
                                                p.getJointState(bot.botId, 3)[0],
                                               endeffektorSpher[0]-goalSpher[step][0],
                                               endeffektorSpher[1]-goalSpher[step][1],
                                               endeffektorSpher[2]-goalSpher[step][2]
                                               ))
                    
                    
##############################################################################################################################################################                    
                    if len(p.getContactPoints(bodyA=bot.botId, bodyB=bot.botId)) > 0:   #Kollision Roboter mit sich selbst
                        if not bot.collisionFlag:
                            collisions += 1
                        bot.collisionFlag = True
                    if len(p.getContactPoints(bodyA=bot.botId, bodyB=bot.planeId)) > 0: #Kollision Roboter Bodenplatte
                        if not bot.collisionFlag:
                            collisions += 1                        
                        bot.collisionFlag = True

                    bot.setMovement(output)

                    
                    bot.moveStep()            
            p.stepSimulation()
            time.sleep(1/240)
            stepCount += 1
        stepCount = 0
        print('Step', step)
        index = 0
        for genome_id, genome in genomes:
            if FF == 1:
                if not bots[index].collisionFlag:
                    isPos = bots[index].getBotHeadPos()
                    isOrientation= bots[index].getBotHeadOrientation()
                    score, orientationScore = fitnessFunction1(isPos, isOrientation, goalKart[step], goalOrientation[step], orVer)
                    bots[index].botScore += score
                    bots[index].orientationScore += orientationScore 
                else:
                    bots[index].botScore += maxDist
                    bots[index].orientationScore[0] += 2*math.pi
                    bots[index].orientationScore[1] += math.pi
                    bots[index].orientationScore[2] += 2*math.pi
            elif FF == 2:
                if not bots[index].collisionFlag:
                    dist = calcDistance(bots[index].stepStartPosition, goalKart[step])
                    orDist = bots[index].calcOrientationDistance(bots[index].stepStartOrientation)
                    score = fitnessFunction2(bots[index].getBotHeadPos(), bots[index].getBotHeadOrientation(), goalKart[step], goalOrientation[step], dist, orDist, orVer)
                    bots[index].botScore += score
            index += 1


        step += 1
        index = 0
           
    for i, (genome_id, genome) in enumerate(genomes):
        if FF == 1:
            d_avg = bots[i].botScore/numOfPoints
            d_jaw = bots[i].orientationScore[0] / numOfPoints
            d_pitch = bots[i].orientationScore[1] / numOfPoints
            d_roll = bots[i].orientationScore[2] / numOfPoints
            if orVer == 0:
                genome.fitness = (1 - d_avg/maxDist) * 100
            else:
                genome.fitness = (1 - d_avg/maxDist) * 100 +  (((1-d_jaw/(2*math.pi))+(1-d_roll/(2*math.pi))+(1-d_pitch/(math.pi)))/3) * 100
        
        if FF == 2:
            genome.fitness = bots[i].botScore/numOfPoints
        print('Fitness:', genome.fitness)
    index = 0
    bestFitness = 0
    for genome_id, genome in genomes:
        if genome.fitness > bestFitness:
            bestFitness = genome.fitness
    fitnessDevelopment.append(bestFitness)
    p.disconnect()

# %%
####Hier wird NEAT gestartet########

global bestGenomes
global fitnessDevelopment
local_dir = file.getPath()
config_path = os.path.join(local_dir, conf)
try:
    import cPickle as pickle  # pylint: disable=import-error
except ImportError:
    import pickle  # pylint: disable=import-error
global pop
config = neat.config.Config(
    neat.DefaultGenome,
    neat.DefaultReproduction,
    neat.DefaultSpeciesSet,
    neat.DefaultStagnation,
    config_path
)
setGlobalGoal(goalPositions) #lädt die Zielpositionen aus der gewählten datei
pop = neat.Population(config)
pop.add_reporter(neat.StdOutReporter(True))
stats = neat.StatisticsReporter()
pop.add_reporter(stats)
p#op.add_reporter(neat.Checkpointer(5)) #Speichert Checkpoints
winner = pop.run(evalGenome, maxGenerations) #hier die maximale Anzahl an Generationen angeben, aktuell 400
    # Save the winner.
with open('winner-ctrnn', 'wb') as f:
    pickle.dump(winner, f)
f.close()
with open('FitnessVerlauf', 'wb') as FV:
    pickle.dump(fitnessDevelopment, FV)
FV.close()
    
print(winner)
# Out:
#  ****** Running generation 0 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 0.0
# Fitness: 3.8401165361446035
# Fitness: 0.0
# Fitness: 4.418938205962516
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 8.874202272044535
# Fitness: 0.0
# Fitness: 4.706080642998701
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 5.037956954738646
# Fitness: 5.678138126535267
# Fitness: 3.433681833632125
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 3.4338239679532108
# Fitness: 0.0
# Fitness: 3.432576265831274
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 14.790818024368665
# Fitness: 25.58888353696132
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 7.4468998279030645
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 10.00244982212384
# Fitness: 4.954724731439972
# Fitness: 30.71555455957993
# Fitness: 3.462283213195726
# Fitness: 8.890553129977151
# Fitness: 0.0
# Fitness: 1.7280359881805427
# Fitness: 1.936538379062164
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 5.967029392083182
# Fitness: 0.0
# Fitness: 0.8756300373397552
# Fitness: 0.06140737713769995
# Fitness: 8.077277518549472
# Fitness: 8.321093239111102
# Population's average fitness: 3.51349 stdev: 6.12635
# Best fitness: 30.71555 - size: (3, 18) - species 1 - id 37
# Average adjusted fitness: 0.114
# Mean genetic distance 1.248, standard deviation 0.292
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0    50     30.7    0.114     0
# Total extinctions: 0
# Generation time: 86.359 sec
#
#  ****** Running generation 1 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 13.912066536056676
# Fitness: 13.750106046721266
# Fitness: 1.7863954880052924
# Fitness: 0.0
# Fitness: 0.28091811097463837
# Fitness: 0.8073546969967428
# Fitness: 3.937623591678262
# Fitness: 16.90949098839804
# Fitness: 13.299607816838313
# Fitness: 2.8147816870547357
# Fitness: 12.1408445435702
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 7.938409353536272
# Fitness: 0.0
# Fitness: 19.051148120664458
# Fitness: 0.0
# Fitness: 0.9081359398012022
# Fitness: 0.0
# Fitness: 13.102819348804918
# Fitness: 17.281416347676327
# Fitness: 0.0
# Fitness: 2.1038928039762195
# Fitness: 9.817858031809346
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 3.546060633457519
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 8.82795048409377
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 9.342162549659168
# Fitness: 0.0
# Fitness: 25.223884146463618
# Fitness: 0.0
# Fitness: 19.658936876272847
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 2.3404673333064916
# Fitness: 1.1732479655360828
# Fitness: 3.110752297697681
# Fitness: 0.0
# Population's average fitness: 4.46133 stdev: 6.69323
# Best fitness: 25.22388 - size: (4, 19) - species 1 - id 90
# Average adjusted fitness: 0.177
# Mean genetic distance 1.149, standard deviation 0.236
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1    50     25.2    0.177     1
# Total extinctions: 0
# Generation time: 86.108 sec (86.233 average)
#
#  ****** Running generation 2 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 0.0
# Fitness: 12.159067208840252
# Fitness: 2.053863705221315
# Fitness: 0.0
# Fitness: 1.2465587936165323
# Fitness: 13.268088528772711
# Fitness: 48.160050095103806
# Fitness: 0.0
# Fitness: 0.8059915994381894
# Fitness: 6.794679966545212
# Fitness: 26.599535749006474
# Fitness: 13.102407381245744
# Fitness: 3.301016729986793
# Fitness: 0.0
# Fitness: 10.813240804854162
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 8.467554336140632
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 2.0466763768311136
# Fitness: 1.8609021665165948
# Fitness: 5.938628891256324
# Fitness: 5.659293560976043
# Fitness: 13.91003512865447
# Fitness: 7.0856965229933
# Fitness: 13.736661747804629
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 10.80886981249299
# Fitness: 2.3704946810344985
# Fitness: 0.0
# Fitness: 13.967336344657976
# Fitness: 0.0
# Fitness: 13.968022798681787
# Fitness: 0.6465943744929248
# Fitness: 10.959612525145248
# Fitness: 0.8059916179632287
# Fitness: 4.421953751859961
# Fitness: 0.0
# Fitness: 11.125628722140515
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 15.012480859721652
# Fitness: 0.9503117396125859
# Fitness: 1.199479662412447
# Fitness: 0.0
# Fitness: 11.306769492073586
# Population's average fitness: 5.89107 stdev: 8.57836
# Best fitness: 48.16005 - size: (3, 17) - species 1 - id 103
# Average adjusted fitness: 0.122
# Mean genetic distance 1.274, standard deviation 0.242
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2    50     48.2    0.122     0
# Total extinctions: 0
# Generation time: 85.142 sec (85.870 average)
#
#  ****** Running generation 3 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 70.7446389388536
# Fitness: 0.0
# Fitness: 10.46094916245267
# Fitness: 0.7368637207608962
# Fitness: 3.6551781403521666
# Fitness: 1.6333616458702305
# Fitness: 0.7370257927715862
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 14.272030006792502
# Fitness: 9.348756476895488
# Fitness: 6.911299981447314
# Fitness: 0.0
# Fitness: 16.806281987352357
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 5.482115176195128
# Fitness: 31.11909871236591
# Fitness: 10.8835328872163
# Fitness: 4.273708518881522
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 8.608393786234812
# Fitness: 4.7298244756949
# Fitness: 0.0
# Fitness: 41.01235283263635
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 7.860497821958672
# Fitness: 47.32838026241917
# Fitness: 0.0
# Fitness: 21.97418885805751
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 21.849650116188805
# Fitness: 16.82581060360216
# Fitness: 12.728102386986679
# Fitness: 20.468485410006338
# Fitness: 8.293656849447911
# Fitness: 0.0
# Fitness: 4.674432541401834
# Fitness: 4.819925667685106
# Fitness: 7.442064631067273
# Fitness: 4.578125545261548
# Population's average fitness: 8.40517 stdev: 13.74793
# Best fitness: 70.74464 - size: (3, 17) - species 1 - id 103
# Average adjusted fitness: 0.119
# Mean genetic distance 1.059, standard deviation 0.249
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3    50     70.7    0.119     0
# Total extinctions: 0
# Generation time: 85.572 sec (85.795 average)
#
#  ****** Running generation 4 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 55.51262586819845
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 52.31635121356661
# Fitness: 24.26381576745593
# Fitness: 6.139857815521924
# Fitness: 16.012501854404185
# Fitness: 6.549717855965798
# Fitness: 3.4730101258421073
# Fitness: 0.0
# Fitness: 6.86936712881
# Fitness: 34.72467798140341
# Fitness: 0.7403145020900359
# Fitness: 6.5497178548446415
# Fitness: 0.0
# Fitness: 16.465917833190563
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 39.57616680801492
# Fitness: 0.0
# Fitness: 26.870639197548734
# Fitness: 35.93265317946626
# Fitness: 4.931358375370264
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.27100616315916315
# Fitness: 11.777653035138744
# Fitness: 30.517662652944303
# Fitness: 0.7403145021161317
# Fitness: 42.294872711845876
# Fitness: 9.551265439631395
# Fitness: 0.0
# Fitness: 38.02467133799671
# Fitness: 1.7925782179775172
# Fitness: 0.0
# Fitness: 28.996879450763192
# Fitness: 14.080889622972999
# Fitness: 38.65111025232485
# Fitness: 0.0
# Fitness: 16.806928138224965
# Fitness: 11.177149248543802
# Fitness: 9.770390260853159
# Fitness: 6.549717859861017
# Fitness: 10.048413542187454
# Fitness: 14.642831150254048
# Fitness: 2.8514587314926865
# Fitness: 29.58496907132341
# Fitness: 0.0
# Fitness: 33.773677650865906
# Fitness: 4.514568558909554
# Population's average fitness: 13.86695 stdev: 15.58948
# Best fitness: 55.51263 - size: (3, 17) - species 1 - id 103
# Average adjusted fitness: 0.250
# Mean genetic distance 0.863, standard deviation 0.283
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4    50     55.5    0.250     1
# Total extinctions: 0
# Generation time: 84.912 sec (85.619 average)
#
#  ****** Running generation 5 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 43.726194200247335
# Fitness: 43.19825472224014
# Fitness: 24.99524671801047
# Fitness: 0.0
# Fitness: 3.885780586188048e-14
# Fitness: 22.96672465222095
# Fitness: 13.511291840478354
# Fitness: 26.736012299612764
# Fitness: 23.23453665392101
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 5.487783600193349
# Fitness: 11.866368080012148
# Fitness: 4.018913477935855
# Fitness: 0.0
# Fitness: 27.20732749626712
# Fitness: 20.408423301170796
# Fitness: 0.0
# Fitness: 30.969515126200555
# Fitness: 0.0
# Fitness: 4.02742344788117
# Fitness: 25.592805913994518
# Fitness: 12.411710622490723
# Fitness: 3.726048136698523e-08
# Fitness: 6.947687330824493
# Fitness: 21.90468006263287
# Fitness: 0.0
# Fitness: 3.5344011981212256
# Fitness: 15.907977377112877
# Fitness: 14.644378306245907
# Fitness: 3.216803531694248
# Fitness: 35.881979746666346
# Fitness: 10.71088119699264
# Fitness: 0.052190200801577324
# Fitness: 29.279142688019828
# Fitness: 0.3378612760489752
# Fitness: 18.528925503225334
# Fitness: 3.3753046497880357
# Fitness: 3.849484237017145
# Fitness: 38.68947958247143
# Fitness: 24.466171663542372
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 14.77088909515401
# Fitness: 2.291038026679922
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Population's average fitness: 11.77496 stdev: 13.06119
# Best fitness: 43.72619 - size: (3, 17) - species 1 - id 103
# Average adjusted fitness: 0.269
# Mean genetic distance 0.946, standard deviation 0.289
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5    50     43.7    0.269     2
# Total extinctions: 0
# Generation time: 84.895 sec (85.498 average)
#
#  ****** Running generation 6 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 56.51539033480502
# Fitness: 25.90949254795087
# Fitness: 0.0
# Fitness: 27.629702084187908
# Fitness: 24.935256773995615
# Fitness: 29.413304690410065
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 13.812976099414982
# Fitness: 11.833777055150993
# Fitness: 31.255533906409312
# Fitness: 0.0
# Fitness: 8.987740619401468
# Fitness: 0.0
# Fitness: 2.1546182909455545
# Fitness: 31.742537565861625
# Fitness: 6.934603257470279
# Fitness: 3.4296201377316393
# Fitness: 15.797452547900942
# Fitness: 17.661333247704533
# Fitness: 9.061638965321759
# Fitness: 15.088515166738711
# Fitness: 36.27027189448222
# Fitness: 17.29880863583201
# Fitness: 26.626320155273554
# Fitness: 20.01235744267992
# Fitness: 32.78861831897867
# Fitness: 9.06182914001384
# Fitness: 25.20243558046875
# Fitness: 9.538542075097634
# Fitness: 0.6029614418775009
# Fitness: 0.0
# Fitness: 7.271317868947991
# Fitness: 9.451816875857855
# Fitness: 21.51305857777469
# Fitness: 6.47948282793476
# Fitness: 13.769988490486693
# Fitness: 0.0
# Fitness: 12.238830709054753
# Fitness: 0.0
# Fitness: 5.794119865413785
# Fitness: 24.625365963062926
# Fitness: 21.62352085603184
# Fitness: 7.482663711838066
# Fitness: 17.799614488487393
# Fitness: 9.582447170470946
# Fitness: 5.123071367999936
# Fitness: 4.864329548773983
# Fitness: 25.185911149698143
# Fitness: 4.621078024256178
# Population's average fitness: 14.13985 stdev: 12.10195
# Best fitness: 56.51539 - size: (3, 17) - species 1 - id 103
# Average adjusted fitness: 0.250
# Mean genetic distance 0.977, standard deviation 0.285
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6    50     56.5    0.250     3
# Total extinctions: 0
# Generation time: 84.394 sec (85.340 average)
#
#  ****** Running generation 7 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 50.23717310829083
# Fitness: 44.5549880989681
# Fitness: 0.0
# Fitness: 18.636143669648643
# Fitness: 0.0
# Fitness: 0.6849240509193566
# Fitness: 15.951080474657228
# Fitness: 35.88957453193548
# Fitness: 36.741849121313706
# Fitness: 6.222866736433011
# Fitness: 24.60781867822636
# Fitness: 22.99542493502094
# Fitness: 5.793967344260212
# Fitness: 46.588751744460446
# Fitness: 11.583862596365055
# Fitness: 19.08817751597951
# Fitness: 31.369078229503636
# Fitness: 0.0
# Fitness: 21.438425692099663
# Fitness: 43.64396627289882
# Fitness: 10.149629327793695
# Fitness: 25.1564421884631
# Fitness: 34.84590565690375
# Fitness: 22.99352367070219
# Fitness: 4.65423532682692
# Fitness: 0.0
# Fitness: 15.804435764244062
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 7.535237332103574
# Fitness: 13.05311733167064
# Fitness: 0.0
# Fitness: 18.616405285003164
# Fitness: 22.855865636677187
# Fitness: 35.62231363838655
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 26.150215979517668
# Fitness: 0.0
# Fitness: 6.300117989871479
# Fitness: 36.862963965155444
# Fitness: 34.69606380960192
# Fitness: 44.71269138702015
# Fitness: 12.389290930628182
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 16.22675884460461
# Fitness: 0.22602901676613274
# Fitness: 39.839313901507175
# Population's average fitness: 17.29437 stdev: 15.76279
# Best fitness: 50.23717 - size: (3, 17) - species 1 - id 103
# Average adjusted fitness: 0.344
# Mean genetic distance 0.917, standard deviation 0.305
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7    50     50.2    0.344     4
# Total extinctions: 0
# Generation time: 83.472 sec (85.107 average)
#
#  ****** Running generation 8 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 0.0
# Fitness: 42.66805492193907
# Fitness: 0.36152136817673264
# Fitness: 44.520401244371506
# Fitness: 53.88066799740941
# Fitness: 9.925947698746539
# Fitness: 44.781445321328434
# Fitness: 20.603304258082222
# Fitness: 0.0
# Fitness: 47.35210887549622
# Fitness: 27.404760576175846
# Fitness: 0.0
# Fitness: 40.60610376827794
# Fitness: 13.122026749379089
# Fitness: 14.153142836137159
# Fitness: 27.870702705074866
# Fitness: 22.405774962884756
# Fitness: 26.328354657983482
# Fitness: 13.767020447852492
# Fitness: 6.759589375828331
# Fitness: 3.4918059385195273
# Fitness: 5.665734875962707
# Fitness: 28.269435178509365
# Fitness: 6.775727624393596
# Fitness: 0.0
# Fitness: 39.931058308939726
# Fitness: 49.154131513606316
# Fitness: 0.0
# Fitness: 50.53533068267916
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 19.465736166718592
# Fitness: 4.835766626285929
# Fitness: 11.6432684220008
# Fitness: 2.2560344576845646
# Fitness: 38.638350634973875
# Fitness: 0.0
# Fitness: 39.61669540447099
# Fitness: 0.0
# Fitness: 37.69747999278585
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 23.66360855579121
# Fitness: 10.075133795097969
# Fitness: 6.895656456269814
# Fitness: 1.4407912887195817
# Fitness: 10.434463891461382
# Fitness: 9.326767344978286
# Fitness: 35.66490600291839
# Population's average fitness: 17.83978 stdev: 17.43698
# Best fitness: 53.88067 - size: (3, 16) - species 1 - id 389
# Average adjusted fitness: 0.331
# Mean genetic distance 1.220, standard deviation 0.332
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8    50     53.9    0.331     5
# Total extinctions: 0
# Generation time: 84.918 sec (85.086 average)
#
#  ****** Running generation 9 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 49.4854842144048
# Fitness: 15.51163110923385
# Fitness: 6.552487987102687
# Fitness: 0.0
# Fitness: 15.967278976662366
# Fitness: 39.918095490294654
# Fitness: 26.051779494004148
# Fitness: 0.0
# Fitness: 14.156446540946703
# Fitness: 37.533611558837194
# Fitness: 16.658844148498215
# Fitness: 0.0
# Fitness: 27.726669742139716
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 3.7994515053116396
# Fitness: 0.0
# Fitness: 9.2507627011736
# Fitness: 24.115544082124046
# Fitness: 29.71404977168944
# Fitness: 0.0
# Fitness: 12.242402510819613
# Fitness: 23.17434373346734
# Fitness: 7.796439568523991
# Fitness: 0.0
# Fitness: 36.09224403695829
# Fitness: 22.756403272649276
# Fitness: 0.0
# Fitness: 23.087275071182297
# Fitness: 0.0
# Fitness: 19.293835544622265
# Fitness: 1.2185236504534258
# Fitness: 2.058812140876396
# Fitness: 7.431770846461916
# Fitness: 2.9935092176001605
# Fitness: 2.914733998755914
# Fitness: 0.0
# Fitness: 20.032641010918034
# Fitness: 11.143536773342406
# Fitness: 5.3634803953595815
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 21.583099574940498
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 31.102713661569158
# Fitness: 37.59818415616051
# Fitness: 3.603986010401794
# Fitness: 0.0
# Population's average fitness: 12.15860 stdev: 13.45646
# Best fitness: 49.48548 - size: (3, 16) - species 1 - id 389
# Average adjusted fitness: 0.246
# Mean genetic distance 1.546, standard deviation 0.265
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9    50     49.5    0.246     6
# Total extinctions: 0
# Generation time: 84.539 sec (85.031 average)
#
#  ****** Running generation 10 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 47.868420737723824
# Fitness: 25.60363015998061
# Fitness: 18.25848400012582
# Fitness: 9.998178331204382
# Fitness: 0.0
# Fitness: 19.48564177211184
# Fitness: 28.182622263281463
# Fitness: 0.0
# Fitness: 16.15032600358524
# Fitness: 0.0
# Fitness: 20.318456096461492
# Fitness: 14.570024299475383
# Fitness: 11.107881413696173
# Fitness: 19.66676583575549
# Fitness: 23.343608585646916
# Fitness: 13.747579796697291
# Fitness: 15.530459202305375
# Fitness: 4.098927975832943
# Fitness: 25.8133623489931
# Fitness: 21.886853100384947
# Fitness: 33.19919946694567
# Fitness: 4.789617935012613
# Fitness: 13.540670738072716
# Fitness: 0.0
# Fitness: 21.851416809375454
# Fitness: 13.024486031312804
# Fitness: 6.027755533691017
# Fitness: 26.425445689653948
# Fitness: 0.0
# Fitness: 19.443423350115044
# Fitness: 21.411218325891035
# Fitness: 5.510681049327152
# Fitness: 11.7560090443106
# Fitness: 3.8961591739879466
# Fitness: 25.76111958711339
# Fitness: 6.888071080668093
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.3249445808113349
# Fitness: 26.476933051434866
# Fitness: 26.628324936709852
# Fitness: 12.18993267777435
# Fitness: 0.0
# Fitness: 23.962185938842424
# Fitness: 0.0
# Fitness: 24.231365169042213
# Fitness: 0.0
# Fitness: 21.588752700497814
# Fitness: 4.383331465322248
# Population's average fitness: 13.77885 stdev: 11.15507
# Best fitness: 47.86842 - size: (3, 16) - species 1 - id 389
# Average adjusted fitness: 0.288
# Mean genetic distance 1.510, standard deviation 0.280
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10    50     47.9    0.288     7
# Total extinctions: 0
# Generation time: 83.915 sec (84.787 average)
#
#  ****** Running generation 11 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 46.03460653261499
# Fitness: 46.314610411669776
# Fitness: 0.7129247352984558
# Fitness: 36.636742073257516
# Fitness: 44.88730943493447
# Fitness: 0.0
# Fitness: 38.507611582263344
# Fitness: 44.23178453040249
# Fitness: 0.0
# Fitness: 43.48688608332732
# Fitness: 26.976774271579973
# Fitness: 42.79468407407649
# Fitness: 33.36776260819455
# Fitness: 1.339561794821975e-10
# Fitness: 27.514609331958418
# Fitness: 45.34723307347268
# Fitness: 43.219219561038415
# Fitness: 7.989498089413824
# Fitness: 17.884830941705655
# Fitness: 44.7143861276994
# Fitness: 41.04390373321661
# Fitness: 10.983217787485412
# Fitness: 39.64815933865053
# Fitness: 2.0372592501871623e-12
# Fitness: 38.04166574103921
# Fitness: 38.3460257739972
# Fitness: 8.302610542838721
# Fitness: 45.186912473060104
# Fitness: 0.16334694384604664
# Fitness: 38.2126349938669
# Fitness: 23.27791598518247
# Fitness: 45.3896728675103
# Fitness: 29.285536282434293
# Fitness: 13.381244032432104
# Fitness: 0.0
# Fitness: 13.650230053511942
# Fitness: 34.66031782123298
# Fitness: 4.1032727410328045
# Fitness: 0.0
# Fitness: 49.05113070664576
# Fitness: 4.932524768764784
# Fitness: 39.203831315162454
# Fitness: 0.16334695000236654
# Fitness: 24.183217529898407
# Fitness: 35.94183480143305
# Fitness: 33.58593728270147
# Fitness: 21.861396675596747
# Fitness: 19.785168091598738
# Fitness: 45.11243328837203
# Fitness: 43.50046182187808
# Population's average fitness: 26.63239 stdev: 17.26433
# Best fitness: 49.05113 - size: (3, 15) - species 1 - id 568
# Average adjusted fitness: 0.543
# Mean genetic distance 1.411, standard deviation 0.239
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11    50     49.1    0.543     8
# Total extinctions: 0
# Generation time: 83.385 sec (84.514 average)
#
#  ****** Running generation 12 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 2.409853149217319
# Fitness: 31.379200058009634
# Fitness: 0.47838291504512237
# Fitness: 12.952250609183432
# Fitness: 38.51039214351894
# Fitness: 0.0
# Fitness: 16.78782647211122
# Fitness: 42.14589400745698
# Fitness: 0.0
# Fitness: 4.207561132118793
# Fitness: 36.98931185463401
# Fitness: 4.529247603822452
# Fitness: 32.498100739314964
# Fitness: 11.950833632405471
# Fitness: 6.675422554237697
# Fitness: 18.069339207611932
# Fitness: 34.79350603159206
# Fitness: 8.506534054657278
# Fitness: 38.74281975461746
# Fitness: 4.147072035020537
# Fitness: 9.445803063923474
# Fitness: 10.836202420926423
# Fitness: 32.977928920317865
# Fitness: 0.0
# Fitness: 26.666620690658696
# Fitness: 11.77571682989012
# Fitness: 20.197642968154486
# Fitness: 37.23246231363635
# Fitness: 11.967745310490567
# Fitness: 7.530648204908081
# Fitness: 30.09193217202698
# Fitness: 44.845620166491265
# Fitness: 5.76882355910004
# Fitness: 3.410397264605168
# Fitness: 10.434101791713871
# Fitness: 0.0
# Fitness: 32.779347549844694
# Fitness: 0.0
# Fitness: 5.87100499254798
# Fitness: 41.48540465064483
# Fitness: 28.952316028118997
# Fitness: 26.11241326254343
# Fitness: 0.0
# Fitness: 4.363061258412861
# Fitness: 30.54378770098365
# Fitness: 30.622381195725268
# Fitness: 0.0
# Fitness: 33.51501289771552
# Fitness: 44.902915102241
# Fitness: 5.773115088943131
# Population's average fitness: 17.87752 stdev: 14.91180
# Best fitness: 44.90292 - size: (3, 13) - species 1 - id 625
# Average adjusted fitness: 0.398
# Mean genetic distance 1.485, standard deviation 0.264
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12    50     44.9    0.398     9
# Total extinctions: 0
# Generation time: 83.931 sec (84.393 average)
#
#  ****** Running generation 13 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 44.593572155839084
# Fitness: 32.997064391830634
# Fitness: 0.0
# Fitness: 7.40646814054376
# Fitness: 6.981825669953011
# Fitness: 16.86440132116784
# Fitness: 30.33916423722014
# Fitness: 13.329769572680295
# Fitness: 34.318143347424375
# Fitness: 11.581145735699101
# Fitness: 0.0
# Fitness: 21.07531742205858
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 23.394087734016537
# Fitness: 0.0
# Fitness: 39.42969661542756
# Fitness: 17.23044566125785
# Fitness: 34.243644357540624
# Fitness: 29.912649907719764
# Fitness: 11.279066544915576
# Fitness: 34.091618479319536
# Fitness: 40.47760554901393
# Fitness: 38.712983177667965
# Fitness: 2.2267090341493203
# Fitness: 0.0
# Fitness: 25.152821100772375
# Fitness: 27.951539160436322
# Fitness: 7.3884944450487335
# Fitness: 0.0
# Fitness: 8.610456191170929
# Fitness: 0.0
# Fitness: 8.265897890763659
# Fitness: 0.0
# Fitness: 40.85080317098031
# Fitness: 29.17838012094675
# Fitness: 0.0
# Fitness: 10.577873311835969
# Fitness: 30.80370163723607
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 40.005189356212405
# Fitness: 3.209683312045751
# Fitness: 23.17087050190682
# Fitness: 0.0
# Fitness: 41.137501453552474
# Fitness: 0.0
# Fitness: 1.6676492907727003
# Fitness: 37.23608416920054
# Population's average fitness: 16.51385 stdev: 15.49398
# Best fitness: 44.59357 - size: (3, 13) - species 1 - id 625
# Average adjusted fitness: 0.370
# Mean genetic distance 1.466, standard deviation 0.386
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13    50     44.6    0.370    10
# Total extinctions: 0
# Generation time: 84.736 sec (84.310 average)
#
#  ****** Running generation 14 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 45.1788349370636
# Fitness: 30.71665470768346
# Fitness: 14.270693010192844
# Fitness: 0.0
# Fitness: 12.923604939203534
# Fitness: 28.856920619499135
# Fitness: 42.37509038216693
# Fitness: 26.832365391480664
# Fitness: 26.998326728032502
# Fitness: 36.31616620010869
# Fitness: 0.0
# Fitness: 43.924795068461684
# Fitness: 43.989645906610825
# Fitness: 26.211995546730556
# Fitness: 39.234539809421115
# Fitness: 43.94060126123727
# Fitness: 16.320375057884373
# Fitness: 8.17325484974616
# Fitness: 41.58603894286123
# Fitness: 30.452014648461216
# Fitness: 0.0
# Fitness: 34.361040217337276
# Fitness: 21.33724897114442
# Fitness: 45.01779634915885
# Fitness: 0.0
# Fitness: 21.094835876927807
# Fitness: 30.337208668515906
# Fitness: 4.047325349448517
# Fitness: 24.872711661900638
# Fitness: 9.466221526246404
# Fitness: 43.73421442024601
# Fitness: 44.94285847880334
# Fitness: 0.0
# Fitness: 21.937937354205154
# Fitness: 29.64948438042976
# Fitness: 47.916131851616555
# Fitness: 30.660706952325732
# Fitness: 40.26859847559097
# Fitness: 0.0
# Fitness: 33.56410113218492
# Fitness: 25.60168688730669
# Fitness: 75.0240599617934
# Fitness: 0.0
# Fitness: 5.629068194363127
# Fitness: 35.57701522450936
# Fitness: 22.748133901217464
# Fitness: 8.212023334461609
# Fitness: 29.62837034243401
# Fitness: 0.0
# Fitness: 0.3496029578743154
# Population's average fitness: 24.88561 stdev: 17.24659
# Best fitness: 75.02406 - size: (6, 18) - species 1 - id 714
# Average adjusted fitness: 0.332
# Mean genetic distance 1.596, standard deviation 0.330
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14    50     75.0    0.332     0
# Total extinctions: 0
# Generation time: 84.201 sec (84.239 average)
#
#  ****** Running generation 15 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 60.165035323274594
# Fitness: 29.892099794841396
# Fitness: 33.98748648515549
# Fitness: 27.073578895409423
# Fitness: 0.0008654933229934603
# Fitness: 0.0
# Fitness: 37.287976020944654
# Fitness: 18.69410168335923
# Fitness: 0.0
# Fitness: 43.535234642687286
# Fitness: 1.0745362488684407e-07
# Fitness: 0.0
# Fitness: 25.184546382403038
# Fitness: 31.64281047131517
# Fitness: 6.1112545533687985
# Fitness: 26.404829087886537
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 45.94137225266635
# Fitness: 0.0
# Fitness: 5.947982914877112
# Fitness: 47.181124676636514
# Fitness: 0.0
# Fitness: 40.617974883492586
# Fitness: 43.95825916612248
# Fitness: 24.67941536552305
# Fitness: 30.741469752010914
# Fitness: 0.0
# Fitness: 46.3894663631165
# Fitness: 36.76689974299123
# Fitness: 16.039811407310946
# Fitness: 7.1327185276486444
# Fitness: 0.0
# Fitness: 38.71276642465851
# Fitness: 28.1530185497544
# Fitness: 17.454718421921328
# Fitness: 0.0
# Fitness: 22.296988398414506
# Fitness: 29.630663420037695
# Fitness: 21.554968416834047
# Fitness: 4.020572763607788e-10
# Fitness: 45.782341595330294
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 40.10569231281793
# Fitness: 1.1098976632402837
# Fitness: 0.0
# Population's average fitness: 18.60355 stdev: 18.20100
# Best fitness: 60.16504 - size: (6, 18) - species 1 - id 714
# Average adjusted fitness: 0.309
# Mean genetic distance 1.667, standard deviation 0.338
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15    50     60.2    0.309     1
# Total extinctions: 0
# Generation time: 85.110 sec (84.260 average)
#
#  ****** Running generation 16 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 67.9639572217754
# Fitness: 7.751698331631862
# Fitness: 32.01359543742301
# Fitness: 0.0
# Fitness: 12.73748671498395
# Fitness: 0.0
# Fitness: 18.13907544698484
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 5.87917633852581
# Fitness: 34.59484527235607
# Fitness: 0.0
# Fitness: 45.491977933529824
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 29.663518057232835
# Fitness: 3.867049540789174
# Fitness: 43.66824315906869
# Fitness: 23.201117234077476
# Fitness: 44.6781983841269
# Fitness: 0.0
# Fitness: 14.334852592246929
# Fitness: 37.644456736220825
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 4.880639897653454
# Fitness: 20.79196386100646
# Fitness: 0.0
# Fitness: 33.7965479559932
# Fitness: 6.284916639104781
# Fitness: 49.27051056199134
# Fitness: 0.0
# Fitness: 39.448779419696855
# Fitness: 0.0
# Fitness: 5.450396249221128
# Fitness: 38.00971663126621
# Fitness: 34.88946250368778
# Fitness: 39.743499353236444
# Fitness: 38.97742118849594
# Fitness: 16.24378285207201
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 18.592946950339392
# Fitness: 0.0
# Fitness: 34.92759842491294
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 3.8656661158402033
# Population's average fitness: 16.13606 stdev: 18.27182
# Best fitness: 67.96396 - size: (6, 18) - species 1 - id 714
# Average adjusted fitness: 0.237
# Mean genetic distance 1.738, standard deviation 0.301
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16    50     68.0    0.237     2
# Total extinctions: 0
# Generation time: 84.943 sec (84.315 average)
#
#  ****** Running generation 17 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 53.56759261363834
# Fitness: 53.83027925664059
# Fitness: 3.5779158410137866
# Fitness: 6.327224015293624
# Fitness: 29.35806113887141
# Fitness: 8.573010833989477
# Fitness: 29.78652062467238
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 36.71570477652088
# Fitness: 20.89603030058448
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 37.35710460901808
# Fitness: 31.47326463161276
# Fitness: 4.380995495113874
# Fitness: 21.65247251352656
# Fitness: 0.0
# Fitness: 34.641253504178046
# Fitness: 6.161799717757641
# Fitness: 0.0
# Fitness: 17.670507651202712
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 18.230442843174806
# Fitness: 0.0
# Fitness: 30.086853145827416
# Fitness: 25.912052779425313
# Fitness: 0.0
# Fitness: 3.5417723699820316
# Fitness: 34.69418194754897
# Fitness: 9.280804304031381
# Fitness: 3.5782409053768007
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 5.121037579500536
# Fitness: 21.273027764835597
# Fitness: 0.0
# Fitness: 26.60653018334623
# Fitness: 27.135821454030385
# Fitness: 38.3895911379397
# Fitness: 31.728182236449662
# Fitness: 28.30985405885126
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 2.973904489947424
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Population's average fitness: 14.05664 stdev: 15.75448
# Best fitness: 53.83028 - size: (5, 17) - species 1 - id 799
# Average adjusted fitness: 0.261
# Mean genetic distance 1.900, standard deviation 0.375
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17    50     53.8    0.261     3
# Total extinctions: 0
# Generation time: 84.733 sec (84.441 average)
#
#  ****** Running generation 18 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 65.88890964634199
# Fitness: 69.98379695192894
# Fitness: 40.77444286049187
# Fitness: 26.14846526756161
# Fitness: 17.082695530835235
# Fitness: 27.40692424646108
# Fitness: 0.26039085915563365
# Fitness: 36.63369095616123
# Fitness: 0.0
# Fitness: 2.2969874607867458
# Fitness: 37.23642496141457
# Fitness: 44.97677332011888
# Fitness: 44.51839435864535
# Fitness: 53.38687562673938
# Fitness: 0.0
# Fitness: 14.338436887196352
# Fitness: 43.698681107514
# Fitness: 56.48835466055757
# Fitness: 47.27308478899213
# Fitness: 5.240944005684311
# Fitness: 11.304708032648513
# Fitness: 51.00974992944278
# Fitness: 43.2897877174451
# Fitness: 0.0
# Fitness: 47.085002776518294
# Fitness: 0.0
# Fitness: 35.893694705350256
# Fitness: 34.86867137292932
# Fitness: 12.524682663828091
# Fitness: 46.896541433741035
# Fitness: 12.977802276681416
# Fitness: 62.060273603038624
# Fitness: 67.48166305351224
# Fitness: 19.488911575691855
# Fitness: 40.68325387315037
# Fitness: 45.67099854964257
# Fitness: 66.85166045656368
# Fitness: 57.40831471451772
# Fitness: 33.24186456467554
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 33.76271234972945
# Fitness: 33.85593106195091
# Fitness: 0.0
# Fitness: 58.442969760809106
# Fitness: 0.16010786141261946
# Fitness: 46.58872565982781
# Fitness: 3.350692439706753
# Fitness: 0.0
# Fitness: 0.0
# Population's average fitness: 29.97066 stdev: 22.80459
# Best fitness: 69.98380 - size: (6, 18) - species 1 - id 714
# Average adjusted fitness: 0.428
# Mean genetic distance 1.672, standard deviation 0.275
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18    50     70.0    0.428     4
# Total extinctions: 0
# Generation time: 83.501 sec (84.299 average)
#
#  ****** Running generation 19 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 62.97016206596594
# Fitness: 57.620806976999575
# Fitness: 0.0
# Fitness: 43.991567867368396
# Fitness: 0.0
# Fitness: 6.882529873798002
# Fitness: 4.928255144210293
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 30.414664994825426
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 46.13966039104876
# Fitness: 32.96140119769225
# Fitness: 0.0
# Fitness: 6.357461231208633
# Fitness: 5.700994692884434
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 3.534734523250743
# Fitness: 4.239685111673367
# Fitness: 39.268452406614635
# Fitness: 54.69428077992874
# Fitness: 3.2641171950686734
# Fitness: 0.0
# Fitness: 38.13761706493331
# Fitness: 17.549232145883515
# Fitness: 5.285503212120988
# Fitness: 5.353124926757703
# Fitness: 37.16443192310156
# Fitness: 1.6157143586104747
# Fitness: 0.7199411889424423
# Fitness: 4.14321575231321
# Fitness: 43.67266510193772
# Fitness: 51.2226004418233
# Fitness: 3.4784857049263787
# Fitness: 46.233263759916866
# Fitness: 9.792310644196865
# Fitness: 0.0
# Fitness: 10.69371816714868
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 23.324166299892628
# Fitness: 5.1427614899872705
# Fitness: 2.380840608193321
# Fitness: 44.388835397960364
# Population's average fitness: 15.06534 stdev: 19.69260
# Best fitness: 62.97016 - size: (6, 18) - species 1 - id 714
# Average adjusted fitness: 0.239
# Mean genetic distance 1.435, standard deviation 0.324
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19    50     63.0    0.239     5
# Total extinctions: 0
# Generation time: 85.876 sec (84.433 average)
#
#  ****** Running generation 20 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 62.85209653919442
# Fitness: 63.73671208134683
# Fitness: 40.33264165191597
# Fitness: 47.92099579993934
# Fitness: 24.514105400910648
# Fitness: 30.61199415338666
# Fitness: 20.70628208777318
# Fitness: 28.515985236097954
# Fitness: 47.85408022887319
# Fitness: 19.090852386773825
# Fitness: 0.0
# Fitness: 48.5517224302114
# Fitness: 46.52589173770424
# Fitness: 7.764828283301935
# Fitness: 34.484354800446596
# Fitness: 62.36694054464093
# Fitness: 5.853913082792296
# Fitness: 38.32066338501151
# Fitness: 0.0
# Fitness: 15.44985341891172
# Fitness: 53.92772094936207
# Fitness: 0.0
# Fitness: 46.01514369375105
# Fitness: 0.661503355084827
# Fitness: 47.33375511708001
# Fitness: 45.83445332591517
# Fitness: 40.05380759400295
# Fitness: 22.512772253012358
# Fitness: 42.450940698152166
# Fitness: 0.0
# Fitness: 21.59248535881865
# Fitness: 41.18605190948265
# Fitness: 50.07398063910424
# Fitness: 0.0
# Fitness: 55.83705461638995
# Fitness: 14.17683007136723
# Fitness: 0.3638248079974349
# Fitness: 56.462251302488085
# Fitness: 47.542124157379675
# Fitness: 60.74824809975846
# Fitness: 38.21503218510057
# Fitness: 49.28324492001835
# Fitness: 20.863722077085455
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 45.64322400077434
# Fitness: 44.68419191878958
# Fitness: 22.029434470315547
# Fitness: 0.0
# Fitness: 11.910492400348557
# Population's average fitness: 30.49712 stdev: 20.83682
# Best fitness: 63.73671 - size: (6, 18) - species 1 - id 897
# Average adjusted fitness: 0.478
# Mean genetic distance 1.082, standard deviation 0.252
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   20    50     63.7    0.478     6
# Total extinctions: 0
# Generation time: 83.828 sec (84.424 average)
#
#  ****** Running generation 21 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 58.081904240157336
# Fitness: 54.37402385301592
# Fitness: 15.945008161006069
# Fitness: 0.0
# Fitness: 27.68241427935983
# Fitness: 28.92307862154927
# Fitness: 6.8285830279670945
# Fitness: 43.61000723135639
# Fitness: 49.173963615634456
# Fitness: 33.91379062546439
# Fitness: 39.365609274324285
# Fitness: 37.2316175645325
# Fitness: 17.031983664392786
# Fitness: 40.64117371793558
# Fitness: 25.442425666343038
# Fitness: 30.93944416077097
# Fitness: 0.0
# Fitness: 36.69262961855657
# Fitness: 37.60800283454505
# Fitness: 10.659023747867618
# Fitness: 36.23322742168392
# Fitness: 0.0
# Fitness: 3.6377793442941084
# Fitness: 6.688510961227524
# Fitness: 0.0
# Fitness: 0.3234811474390209
# Fitness: 28.875484823923024
# Fitness: 34.730857425502435
# Fitness: 46.23956806850154
# Fitness: 22.893419288629197
# Fitness: 34.82128144941889
# Fitness: 35.51503003870083
# Fitness: 52.69334931687702
# Fitness: 17.564374189865664
# Fitness: 9.547918011776346e-14
# Fitness: 8.042173168240828
# Fitness: 35.32065694263054
# Fitness: 49.447466120486396
# Fitness: 14.46865044930934
# Fitness: 18.026868353642488
# Fitness: 56.89396205263231
# Fitness: 35.632334423752404
# Fitness: 43.369947457095066
# Fitness: 0.0
# Fitness: 21.594146578372396
# Fitness: 38.54618264187875
# Fitness: 17.071866355601955
# Fitness: 39.90171120664259
# Fitness: 47.02441869879666
# Fitness: 6.854125950162986
# Population's average fitness: 26.93111 stdev: 17.43636
# Best fitness: 58.08190 - size: (6, 18) - species 1 - id 897
# Average adjusted fitness: 0.464
# Mean genetic distance 1.272, standard deviation 0.333
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   21    50     58.1    0.464     7
# Total extinctions: 0
# Generation time: 84.186 sec (84.504 average)
#
#  ****** Running generation 22 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 56.93944204361485
# Fitness: 8.059001940735406
# Fitness: 6.979438409215097
# Fitness: 0.0
# Fitness: 5.2286522113751115
# Fitness: 61.30212865677407
# Fitness: 24.151668481709592
# Fitness: 11.607205912243561
# Fitness: 60.160759931564826
# Fitness: 5.1583320834991735
# Fitness: 5.921211115408611
# Fitness: 38.080539976698844
# Fitness: 48.857550349657735
# Fitness: 5.341625869405806
# Fitness: 26.332696542663165
# Fitness: 23.934639778127398
# Fitness: 0.0
# Fitness: 60.494525034553234
# Fitness: 53.90863229946476
# Fitness: 34.43265974846228
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 6.248004316772171
# Fitness: 0.0
# Fitness: 38.30375783505682
# Fitness: 50.57957505869565
# Fitness: 41.421205864816905
# Fitness: 29.22783120471277
# Fitness: 50.70476000550387
# Fitness: 66.6210131923207
# Fitness: 69.20156054052165
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 3.293428879783291
# Fitness: 0.0
# Fitness: 8.479977390904892
# Fitness: 0.13987109470995684
# Fitness: 0.0
# Fitness: 38.03661028266498
# Fitness: 34.94039080867566
# Fitness: 0.0
# Fitness: 6.315691461359793
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 37.31329915681007
# Fitness: 40.436059843389415
# Fitness: 43.20826332934297
# Fitness: 0.0
# Fitness: 48.54537521040301
# Population's average fitness: 22.99815 stdev: 23.00069
# Best fitness: 69.20156 - size: (7, 19) - species 1 - id 1087
# Average adjusted fitness: 0.332
# Mean genetic distance 1.234, standard deviation 0.295
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   22    50     69.2    0.332     8
# Total extinctions: 0
# Generation time: 85.590 sec (84.670 average)
#
#  ****** Running generation 23 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 12.276855946974791
# Fitness: 48.29649432585927
# Fitness: 0.0
# Fitness: 33.4484136739546
# Fitness: 6.296259019574057
# Fitness: 28.95687764793226
# Fitness: 41.85079790086198
# Fitness: 4.546760637277133
# Fitness: 2.572898930752796
# Fitness: 36.789189598384894
# Fitness: 20.317599532649812
# Fitness: 0.714400682235915
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 38.13811181878397
# Fitness: 45.691260391518334
# Fitness: 0.0
# Fitness: 8.836598465141238
# Fitness: 43.18362890474143
# Fitness: 10.923976060345359
# Fitness: 20.666374489692593
# Fitness: 14.120838894471081
# Fitness: 33.88761191588081
# Fitness: 9.909193094215345
# Fitness: 6.134223860771847
# Fitness: 0.0
# Fitness: 8.391625129184392
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 24.416165391315722
# Fitness: 0.0
# Fitness: 47.56345502199618
# Fitness: 28.12480779503138
# Fitness: 30.275303581705423
# Fitness: 0.0
# Fitness: 8.687117643022265
# Fitness: 4.849057808599847
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 37.4506161651635
# Fitness: 28.500429393311673
# Fitness: 3.052947330904968
# Fitness: 0.0
# Fitness: 3.895820183688746
# Fitness: 0.0
# Fitness: 35.53770070318386
# Fitness: 12.294499862896247
# Fitness: 46.96382672588373
# Fitness: 0.0
# Population's average fitness: 15.75123 stdev: 16.57121
# Best fitness: 48.29649 - size: (7, 19) - species 1 - id 1086
# Average adjusted fitness: 0.326
# Mean genetic distance 1.332, standard deviation 0.337
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   23    50     48.3    0.326     9
# Total extinctions: 0
# Generation time: 85.798 sec (84.776 average)
#
#  ****** Running generation 24 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 46.94788736521574
# Fitness: 47.97855913265992
# Fitness: 26.705807140074036
# Fitness: 27.34954677249676
# Fitness: 0.0
# Fitness: 8.696257061648561
# Fitness: 38.098411365514714
# Fitness: 0.0
# Fitness: 27.381137407969867
# Fitness: 31.022055476744384
# Fitness: 25.916724747911495
# Fitness: 49.77475753890786
# Fitness: 2.4006004155306915
# Fitness: 31.167687483515284
# Fitness: 13.312721698961036
# Fitness: 19.86049113555486
# Fitness: 2.052576468743289
# Fitness: 0.0
# Fitness: 51.5605968329847
# Fitness: 0.0
# Fitness: 43.41216373523109
# Fitness: 0.0
# Fitness: 24.336808104709863
# Fitness: 34.113691428964636
# Fitness: 30.20140202000527
# Fitness: 0.0
# Fitness: 4.322166675939945
# Fitness: 33.63324360810071
# Fitness: 18.251757368622616
# Fitness: 26.842015569765227
# Fitness: 8.397338603038728
# Fitness: 32.31809914357086
# Fitness: 48.127645531316375
# Fitness: 30.64630729577965
# Fitness: 30.06535064693311
# Fitness: 48.32447613955816
# Fitness: 2.4006004155306884
# Fitness: 30.061637622589302
# Fitness: 15.802165018314748
# Fitness: 24.33942898288936
# Fitness: 0.0
# Fitness: 9.962929537843385
# Fitness: 29.46867399083551
# Fitness: 0.0
# Fitness: 32.159437781215196
# Fitness: 0.0
# Fitness: 29.32329381560827
# Fitness: 47.786110410046994
# Fitness: 8.415220019045911
# Fitness: 6.580507109583316
# Population's average fitness: 21.99037 stdev: 16.59232
# Best fitness: 51.56060 - size: (7, 20) - species 1 - id 1171
# Average adjusted fitness: 0.426
# Mean genetic distance 1.312, standard deviation 0.385
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   24    50     51.6    0.426    10
# Total extinctions: 0
# Generation time: 83.743 sec (84.731 average)
#
#  ****** Running generation 25 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 64.63512435953187
# Fitness: 67.42847886146453
# Fitness: 11.929450852435972
# Fitness: 25.721438799365245
# Fitness: 24.84555597011334
# Fitness: 4.263509204964719
# Fitness: 50.881878466220414
# Fitness: 53.09035251053431
# Fitness: 16.14938485363146
# Fitness: 0.0
# Fitness: 30.715896045540063
# Fitness: 28.153726601418377
# Fitness: 43.83928330609048
# Fitness: 64.8921496519314
# Fitness: 6.008655683751402
# Fitness: 4.222609125090396
# Fitness: 31.856988505104887
# Fitness: 45.988386791197385
# Fitness: 73.56075420428934
# Fitness: 4.543047796821144
# Fitness: 20.82623814546882
# Fitness: 2.8183732830430666
# Fitness: 5.86850636009183
# Fitness: 61.843556936927165
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 42.6672392063838
# Fitness: 26.240763198853436
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 2.16519076030387
# Fitness: 5.374657110499768
# Fitness: 12.42545759787989
# Fitness: 48.2050078079399
# Fitness: 9.617169868462229
# Fitness: 39.47162988598528
# Fitness: 6.78032037650978
# Fitness: 38.006673808769904
# Fitness: 61.11361141619187
# Fitness: 0.0
# Fitness: 41.52841979152454
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 49.041062416328906
# Fitness: 24.662260882732586
# Fitness: 4.607976549289193
# Fitness: 19.310226219608747
# Fitness: 34.85665573933794
# Fitness: 48.169512184765125
# Fitness: 5.235056372498525
# Population's average fitness: 25.27124 stdev: 22.48413
# Best fitness: 73.56075 - size: (7, 19) - species 1 - id 1219
# Average adjusted fitness: 0.344
# Mean genetic distance 1.608, standard deviation 0.365
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   25    50     73.6    0.344    11
# Total extinctions: 0
# Generation time: 85.582 sec (84.778 average)
#
#  ****** Running generation 26 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 63.68130711488889
# Fitness: 45.9515119634727
# Fitness: 52.90625307014837
# Fitness: 32.729474469129975
# Fitness: 36.87729995748238
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 25.717785986436525
# Fitness: 41.408474991604706
# Fitness: 16.693692450861505
# Fitness: 28.825160200470737
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 55.80813638599028
# Fitness: 0.0
# Fitness: 5.776288993545203
# Fitness: 1.5954544248656821
# Fitness: 0.0
# Fitness: 42.16847040049202
# Fitness: 23.68033689227419
# Fitness: 32.24254541059845
# Fitness: 36.15326459870987
# Fitness: 27.43691928342691
# Fitness: 52.73594128675452
# Fitness: 0.0
# Fitness: 43.076930470301264
# Fitness: 0.0
# Fitness: 37.82663670828768
# Fitness: 44.501467151448495
# Fitness: 0.0
# Fitness: 20.63715761161891
# Fitness: 3.04290628675288
# Fitness: 0.0
# Fitness: 16.688937619536762
# Fitness: 16.35565951589878
# Fitness: 12.454817039420428
# Fitness: 7.514544280117095
# Fitness: 0.0
# Fitness: 25.782863199844105
# Fitness: 0.0
# Fitness: 38.62572747891177
# Fitness: 54.17029914159845
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 57.34733545370517
# Fitness: 23.956167230289765
# Fitness: 36.43743996877817
# Fitness: 53.17326348706415
# Population's average fitness: 22.27961 stdev: 20.49488
# Best fitness: 63.68131 - size: (7, 19) - species 1 - id 1219
# Average adjusted fitness: 0.350
# Mean genetic distance 1.842, standard deviation 0.331
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   26    50     63.7    0.350    12
# Total extinctions: 0
# Generation time: 83.868 sec (84.670 average)
#
#  ****** Running generation 27 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 62.70207118171071
# Fitness: 56.0627650760365
# Fitness: 0.0
# Fitness: 57.664494902393265
# Fitness: 46.38494948262975
# Fitness: 17.32846679846055
# Fitness: 0.0
# Fitness: 44.37347726168689
# Fitness: 0.0003921948855800661
# Fitness: 27.661808912920566
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 38.18697605026126
# Fitness: 0.0
# Fitness: 32.66468019657197
# Fitness: 41.02612449981313
# Fitness: 49.21332701782951
# Fitness: 31.83362348113975
# Fitness: 42.91908219336851
# Fitness: 38.41373493167988
# Fitness: 60.64733269770336
# Fitness: 47.995171329528134
# Fitness: 0.0
# Fitness: 5.486151860120079
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 27.732358144622026
# Fitness: 12.255455857041586
# Fitness: 0.0
# Fitness: 11.408861316361236
# Fitness: 0.0
# Fitness: 4.859108034022716
# Fitness: 0.0
# Fitness: 13.421518088997132
# Fitness: 27.294684009687757
# Fitness: 15.821275602682158
# Fitness: 10.861986425379794
# Fitness: 64.0583290149356
# Fitness: 0.0
# Fitness: 68.30926732711777
# Fitness: 55.95399604222111
# Fitness: 60.96041394109761
# Fitness: 41.34735797360381
# Fitness: 46.10570358195376
# Fitness: 63.09559161620439
# Fitness: 6.00519472143542
# Fitness: 36.450655739158265
# Fitness: 51.09140673979519
# Fitness: 48.37250492927102
# Population's average fitness: 27.31941 stdev: 23.39054
# Best fitness: 68.30927 - size: (8, 19) - species 1 - id 1337
# Average adjusted fitness: 0.400
# Mean genetic distance 1.572, standard deviation 0.301
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   27    50     68.3    0.400    13
# Total extinctions: 0
# ...
# Fitness: 55.23123044712554
# Fitness: 47.765223053564284
# Fitness: 44.93950110959567
# Fitness: 94.8997383406243
# Fitness: 94.39681302947523
# Fitness: 58.36420017364302
# Fitness: 49.688199870654444
# Fitness: 66.5377981817402
# Fitness: 47.62052844027228
# Fitness: 0.0
# Fitness: 8.885658521472596
# Fitness: 82.9802446011281
# Fitness: 54.76475130464502
# Fitness: 67.35525494567648
# Fitness: 88.49217039326186
# Fitness: 90.91180858932373
# Fitness: 74.94430377112776
# Fitness: 67.21873892872237
# Fitness: 65.07606533874632
# Fitness: 87.93624470147026
# Fitness: 64.11411699942515
# Fitness: 82.52093519595888
# Fitness: 50.34515583765759
# Fitness: 62.94838024376185
# Fitness: 66.29777365637061
# Fitness: 54.205837020694425
# Fitness: 51.254648136247795
# Fitness: 68.70024665730594
# Fitness: 54.81631308164975
# Population's average fitness: 58.24565 stdev: 21.05675
# Best fitness: 94.89974 - size: (8, 9) - species 5 - id 7870
# Average adjusted fitness: 0.610
# Mean genetic distance 1.562, standard deviation 0.481
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   62    22     86.7    0.557     7
#      5   61    28     94.9    0.662     7
# Total extinctions: 0
# Generation time: 82.209 sec (82.454 average)
#
#  ****** Running generation 182 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 77.75276727145976
# Fitness: 75.532303058577
# Fitness: 66.42013536315167
# Fitness: 57.560774865486316
# Fitness: 3.561390209818456
# Fitness: 62.920084803431244
# Fitness: 78.36934578910517
# Fitness: 68.19229611163777
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 75.67141775160886
# Fitness: 18.79524944473393
# Fitness: 76.70338498325347
# Fitness: 0.0
# Fitness: 77.00140780375874
# Fitness: 39.649026685154595
# Fitness: 32.513040525494254
# Fitness: 16.83437037584032
# Fitness: 24.62909276922648
# Fitness: 15.312203864679294
# Fitness: 21.70796590359506
# Fitness: 62.07226225130928
# Fitness: 82.91517949063773
# Fitness: 82.91628183494421
# Fitness: 76.44553255408759
# Fitness: 0.7534534917088664
# Fitness: 67.21388013668658
# Fitness: 66.99940105220055
# Fitness: 80.71759730131981
# Fitness: 53.99384098061105
# Fitness: 65.14694356449851
# Fitness: 79.95430062966686
# Fitness: 75.37907668147884
# Fitness: 80.30045620421009
# Fitness: 7.842870829442035
# Fitness: 68.33314592634994
# Fitness: 0.0
# Fitness: 42.438893830034814
# Fitness: 78.05306040568748
# Fitness: 65.83719394281083
# Fitness: 81.83296320523766
# Fitness: 13.631420867890379
# Fitness: 74.81962582133973
# Fitness: 27.40554377150906
# Fitness: 59.526643877104654
# Fitness: 17.313982256099557
# Fitness: 39.84921972478869
# Fitness: 90.55477291963386
# Fitness: 60.64609074572577
# Fitness: 67.34439459494014
# Population's average fitness: 51.18729 stdev: 28.99504
# Best fitness: 90.55477 - size: (7, 9) - species 5 - id 8433
# Average adjusted fitness: 0.556
# Mean genetic distance 1.465, standard deviation 0.537
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   63    21     78.4    0.477     8
#      5   62    29     90.6    0.634     8
# Total extinctions: 0
# Generation time: 83.485 sec (82.501 average)
#
#  ****** Running generation 183 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 75.02119240600618
# Fitness: 73.85716511342585
# Fitness: 58.500114918855914
# Fitness: 0.33760148983288385
# Fitness: 50.52567606022912
# Fitness: 71.15384306714655
# Fitness: 35.48281820187026
# Fitness: 12.364952064203468
# Fitness: 9.083208917978505
# Fitness: 12.388099754078675
# Fitness: 22.851495193531235
# Fitness: 59.7861515752081
# Fitness: 67.35095528812413
# Fitness: 75.5228167398831
# Fitness: 40.65870187045907
# Fitness: 57.81344138164312
# Fitness: 69.12361887121968
# Fitness: 0.0
# Fitness: 44.60946159959106
# Fitness: 43.80378226920875
# Fitness: 73.81686426248561
# Fitness: 77.91124292243406
# Fitness: 90.82782097433281
# Fitness: 74.89299269678122
# Fitness: 61.21959401216196
# Fitness: 63.81117617077715
# Fitness: 12.700242921827757
# Fitness: 47.50933466033994
# Fitness: 47.4965572569849
# Fitness: 59.069012778502156
# Fitness: 48.28694905543905
# Fitness: 56.3972506184066
# Fitness: 56.22865324170162
# Fitness: 43.134495282212725
# Fitness: 54.475339681152704
# Fitness: 93.21574950520625
# Fitness: 8.427815970430771
# Fitness: 46.927967986089
# Fitness: 16.100844466013346
# Fitness: 7.427946158602855
# Fitness: 47.604712975097385
# Fitness: 28.262528641039616
# Fitness: 57.33972682439422
# Fitness: 8.351190037239807
# Fitness: 46.8949920467372
# Fitness: 61.394404796873815
# Fitness: 82.36110116094184
# Fitness: 66.25338919129646
# Fitness: 25.969766805587415
# Fitness: 76.101961039561
# Population's average fitness: 48.41293 stdev: 24.80601
# Best fitness: 93.21575 - size: (6, 5) - species 5 - id 8467
# Average adjusted fitness: 0.515
# Mean genetic distance 1.445, standard deviation 0.536
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   64    22     75.5    0.487     9
#      5   63    28     93.2    0.543     9
# Total extinctions: 0
# Generation time: 81.271 sec (82.403 average)
#
#  ****** Running generation 184 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 10.502344906748922
# Fitness: 85.24269723373547
# Fitness: 0.0
# Fitness: 64.49941036376785
# Fitness: 80.96934779257262
# Fitness: 34.6338658777979
# Fitness: 68.7151725145342
# Fitness: 8.70643676491667
# Fitness: 58.610908257171204
# Fitness: 58.50991330707537
# Fitness: 77.12208549725466
# Fitness: 81.89925245411797
# Fitness: 18.61500511049703
# Fitness: 56.17573021086853
# Fitness: 58.77793958700911
# Fitness: 34.71933487777617
# Fitness: 13.595617725284379
# Fitness: 82.9210352920807
# Fitness: 58.827795052114865
# Fitness: 57.21979613522634
# Fitness: 72.55683044377274
# Fitness: 10.995617412498442
# Fitness: 95.62936360930144
# Fitness: 94.40384521491801
# Fitness: 82.28348577680151
# Fitness: 15.696953146855332
# Fitness: 52.657838773870694
# Fitness: 71.84605349610821
# Fitness: 79.49511855693811
# Fitness: 62.45977034956379
# Fitness: 31.160782060007165
# Fitness: 0.0
# Fitness: 81.47256779657496
# Fitness: 42.7728509003695
# Fitness: 78.95490862384636
# Fitness: 70.041484359463
# Fitness: 74.44436990942265
# Fitness: 61.96320353038311
# Fitness: 0.0
# Fitness: 52.407542643615535
# Fitness: 61.7596049724792
# Fitness: 1.1443985752170416
# Fitness: 53.336154735919976
# Fitness: 72.3544654502029
# Fitness: 77.83494636231725
# Fitness: 51.183957075968294
# Fitness: 60.617812654081646
# Fitness: 60.31602556228406
# Fitness: 27.32879843179984
# Fitness: 6.862906677630309
# Population's average fitness: 52.28491 stdev: 27.88446
# Best fitness: 95.62936 - size: (6, 5) - species 5 - id 8467
# Average adjusted fitness: 0.544
# Mean genetic distance 1.476, standard deviation 0.489
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   65    23     85.2    0.520    10
#      5   64    27     95.6    0.568    10
# Total extinctions: 0
# Generation time: 82.206 sec (82.507 average)
#
#  ****** Running generation 185 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 83.5915212648526
# Fitness: 79.82448881916098
# Fitness: 0.0
# Fitness: 12.197647579822569
# Fitness: 40.81647189999351
# Fitness: 66.32194649270994
# Fitness: 58.27932196120398
# Fitness: 29.365739393938362
# Fitness: 0.0
# Fitness: 83.07859616655591
# Fitness: 82.32938489355368
# Fitness: 13.87982035688172
# Fitness: 0.0
# Fitness: 77.16960615458768
# Fitness: 3.338408077241251
# Fitness: 0.0
# Fitness: 48.74526752429572
# Fitness: 15.857874653323131
# Fitness: 54.16276322568213
# Fitness: 25.742236407993886
# Fitness: 36.98023066326699
# Fitness: 37.586420384641976
# Fitness: 0.0
# Fitness: 95.32781584349053
# Fitness: 93.55333957808341
# Fitness: 55.276070114644185
# Fitness: 80.55917649062087
# Fitness: 0.0
# Fitness: 1.4049107289530527
# Fitness: 68.94034043727882
# Fitness: 0.0
# Fitness: 50.97264484774197
# Fitness: 51.3912210026136
# Fitness: 82.04056309012564
# Fitness: 86.21705770298412
# Fitness: 60.49427599470387
# Fitness: 60.51106482734457
# Fitness: 41.658528527482396
# Fitness: 1.620562255521817
# Fitness: 4.710163102720601
# Fitness: 2.3635532343248156
# Fitness: 76.5634892530961
# Fitness: 3.035222264368794
# Fitness: 85.78253175611141
# Fitness: 60.43269992969124
# Fitness: 56.06808965605774
# Fitness: 62.7079506048545
# Fitness: 0.0
# Fitness: 97.65324067390955
# Fitness: 65.78806698949653
# Population's average fitness: 43.88681 stdev: 33.11323
# Best fitness: 97.65324 - size: (7, 8) - species 5 - id 8572
# Average adjusted fitness: 0.444
# Mean genetic distance 1.449, standard deviation 0.471
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   66    22     83.6    0.378    11
#      5   65    28     97.7    0.510     0
# Total extinctions: 0
# Generation time: 83.489 sec (82.658 average)
#
#  ****** Running generation 186 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 74.30663539639542
# Fitness: 67.9505325828039
# Fitness: 11.142598651865223
# Fitness: 20.542868103179952
# Fitness: 44.67925349217518
# Fitness: 87.25272271488019
# Fitness: 21.506076493735684
# Fitness: 11.172143399778195
# Fitness: 0.5881075103388433
# Fitness: 16.093783853555475
# Fitness: 67.83996558719541
# Fitness: 20.56157477859085
# Fitness: 79.71077917070812
# Fitness: 55.90544186667754
# Fitness: 58.104871810133886
# Fitness: 22.07539907467941
# Fitness: 61.48084363931338
# Fitness: 66.76582716982799
# Fitness: 58.22627207393847
# Fitness: 13.781659144804602
# Fitness: 37.08965652645695
# Fitness: 36.88753894626165
# Fitness: 76.30928737103362
# Fitness: 79.54557958566117
# Fitness: 10.800341423308042
# Fitness: 53.15759755004986
# Fitness: 24.070036179527747
# Fitness: 64.16444021854113
# Fitness: 19.607772565907247
# Fitness: 18.186393255369957
# Fitness: 40.21233552197464
# Fitness: 44.83958529364368
# Fitness: 58.351315022319525
# Fitness: 11.17299728032113
# Fitness: 20.1493107795865
# Fitness: 45.210478406026155
# Fitness: 49.97611786830885
# Fitness: 29.07386184676427
# Fitness: 76.66612930869101
# Fitness: 11.2082434995086
# Fitness: 44.475287804111005
# Fitness: 61.956846379028924
# Fitness: 55.79516130014538
# Fitness: 58.70285667827585
# Fitness: 51.787391153559646
# Fitness: 0.0
# Fitness: 45.1414956748856
# Fitness: 58.06749179406753
# Fitness: 45.236092609392045
# Fitness: 52.31470203656761
# Population's average fitness: 42.79687 stdev: 23.32072
# Best fitness: 87.25272 - size: (7, 11) - species 4 - id 8577
# Average adjusted fitness: 0.490
# Mean genetic distance 1.659, standard deviation 0.396
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   67    23     87.3    0.486    12
#      5   66    27     79.5    0.494     1
# Total extinctions: 0
# Generation time: 83.020 sec (82.445 average)
#
#  ****** Running generation 187 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 96.2937974114569
# Fitness: 24.776441164767807
# Fitness: 56.286825204259195
# Fitness: 10.16595189698094
# Fitness: 5.93526155902338
# Fitness: 61.07249724978228
# Fitness: 81.10331946192522
# Fitness: 75.77806093680195
# Fitness: 54.71878294289879
# Fitness: 61.13632380699821
# Fitness: 60.32483962852969
# Fitness: 51.26803137181425
# Fitness: 33.11772911013223
# Fitness: 50.51987215628872
# Fitness: 32.64048706269567
# Fitness: 53.84744692092661
# Fitness: 52.679178592047506
# Fitness: 52.71070408718326
# Fitness: 52.62858813641575
# Fitness: 52.19462661942591
# Fitness: 63.62548852700123
# Fitness: 0.0
# Fitness: 52.60419788104591
# Fitness: 58.36146905651056
# Fitness: 80.1826253188271
# Fitness: 61.13235340552376
# Fitness: 50.87281796386807
# Fitness: 94.39267071485249
# Fitness: 85.07174948448082
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 59.58826640539449
# Fitness: 51.28968887429687
# Fitness: 51.90941462492915
# Fitness: 4.349142370137174
# Fitness: 53.15379804699786
# Fitness: 57.107963152175614
# Fitness: 52.61325805434598
# Fitness: 57.26240939081
# Fitness: 0.0
# Fitness: 83.90458305382462
# Fitness: 82.25635923339162
# Fitness: 52.93993488330574
# Fitness: 55.232643064253296
# Fitness: 3.975738411515766
# Fitness: 85.56399736394238
# Fitness: 82.69005440814117
# Fitness: 61.034458010150956
# Fitness: 55.336789324237245
# Population's average fitness: 50.31301 stdev: 26.49797
# Best fitness: 96.29380 - size: (6, 5) - species 5 - id 8467
# Average adjusted fitness: 0.522
# Mean genetic distance 1.770, standard deviation 0.440
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      4   68    24     94.4    0.510    13
#      5   67    26     96.3    0.533     2
# Total extinctions: 0
# Generation time: 82.681 sec (82.506 average)
#
#  ****** Running generation 188 ******
#
# Step 0
# Step 1
# Step 2
# Step 3
# Step 4
# Step 5
# Step 6
# Step 7
# Step 8
# Step 9
# Fitness: 93.57433577715463
# Fitness: 86.09120230756147
# Fitness: 55.69421000337686
# Fitness: 57.18125790229597
# Fitness: 81.34998196372581
# Fitness: 25.960297505475722
# Fitness: 67.73145126906202
# Fitness: 57.68833977109066
# Fitness: 98.07677091714437
# Fitness: 19.3030169690616
# Fitness: 68.02433889288172
# Fitness: 66.86706500776135
# Fitness: 68.11692370899596
# Fitness: 87.34414745223242
# Fitness: 49.566229990575415
# Fitness: 58.29498206257748
# Fitness: 59.98245848576189
# Fitness: 80.84041687041825
# Fitness: 20.257149089516112
# Fitness: 80.92745771760363
# Fitness: 65.65044019262942
# Fitness: 0.0
# Fitness: 31.567389843219768
# Fitness: 28.208093134262423
# Fitness: 96.32378872810398
# Fitness: 81.02046159118417
# Fitness: 67.10917936843673
# Fitness: 72.91177195891132
# Fitness: 0.0
# Fitness: 72.18388850577844
# Fitness: 0.0
# Fitness: 0.0
# Fitness: 26.093895166105973
# Fitness: 58.91365676561365
# Fitness: 68.45824015970547
# Fitness: 22.10294965854792
# Fitness: 55.87545787266331
# Fitness: 20.066233441528766
# Fitness: 0.0
# Fitness: 68.64886099511108
# Fitness: 92.87611076254841
# Fitness: 68.4549760847843
# Fitness: 15.918554226785517
# Fitness: 0.0
# Fitness: 65.30317133400231
# Fitness: 62.19873064334506
# Fitness: 68.68680905644615
# Fitness: 62.06502735334019
# Fitness: 58.61900920751775
# Fitness: 57.98315192238037
# Population's average fitness: 53.40224 stdev: 28.65994
# Best fitness: 98.07677 - size: (7, 11) - species 4 - id 8672
#
# Best individual in generation 188 meets fitness threshold - complexity: (7, 11)
# Key: 8672
# Fitness: 98.07677091714437
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=0.1044098975352862, response=1.0, activation=sigmoid, aggregation=sum)
# 	1 DefaultNodeGene(key=1, bias=-1.2607163617910704, response=1.0, activation=sigmoid, aggregation=sum)
# 	2 DefaultNodeGene(key=2, bias=6.989019307233976, response=1.0, activation=sigmoid, aggregation=sum)
# 	767 DefaultNodeGene(key=767, bias=0.8798526506305059, response=1.0, activation=sigmoid, aggregation=sum)
# 	1073 DefaultNodeGene(key=1073, bias=2.567074273964608, response=1.0, activation=sigmoid, aggregation=sum)
# 	1341 DefaultNodeGene(key=1341, bias=0.015094836478336926, response=1.0, activation=sigmoid, aggregation=sum)
# 	1726 DefaultNodeGene(key=1726, bias=-1.619515393650761, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-6, 0), weight=-12.87748582021204, enabled=True)
# 	DefaultConnectionGene(key=(-5, 1), weight=-8.246421739925314, enabled=True)
# 	DefaultConnectionGene(key=(-5, 2), weight=1.2869872413567487, enabled=False)
# 	DefaultConnectionGene(key=(-4, 1341), weight=7.028230752707674, enabled=True)
# 	DefaultConnectionGene(key=(-3, 767), weight=-1.060308114002792, enabled=True)
# 	DefaultConnectionGene(key=(-3, 1073), weight=0.9711025698949928, enabled=True)
# 	DefaultConnectionGene(key=(-2, 767), weight=0.4757060640669523, enabled=True)
# 	DefaultConnectionGene(key=(-2, 1726), weight=0.8879118614735007, enabled=True)
# 	DefaultConnectionGene(key=(-1, 767), weight=-1.2250811866353075, enabled=False)
# 	DefaultConnectionGene(key=(767, 1), weight=1.3939005563000697, enabled=True)
# 	DefaultConnectionGene(key=(1073, 2), weight=-2.9049037969706974, enabled=True)
# 	DefaultConnectionGene(key=(1341, 2), weight=-7.046068526296344, enabled=True)
# 	DefaultConnectionGene(key=(1726, 1073), weight=2.60241267276117, enabled=True)
